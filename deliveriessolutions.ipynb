# %%
import pandas as pd

# %%
deliveries=pd.read_csv(r'C:\Users\user\Desktop\EXACKT\Dataset 2\IPL Dataset Full Stuff\deliveries.csv')

# %%
deliveries
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1        Kolkata Knight Riders
# 1              1       1        Kolkata Knight Riders
# 2              1       1        Kolkata Knight Riders
# 3              1       1        Kolkata Knight Riders
# 4              1       1        Kolkata Knight Riders
# 5              1       1        Kolkata Knight Riders
# 6              1       1        Kolkata Knight Riders
# 7              1       1        Kolkata Knight Riders
# 8              1       1        Kolkata Knight Riders
# 9              1       1        Kolkata Knight Riders
# 10             1       1        Kolkata Knight Riders
# 11             1       1        Kolkata Knight Riders
# 12             1       1        Kolkata Knight Riders
# 13             1       1        Kolkata Knight Riders
# 14             1       1        Kolkata Knight Riders
# 15             1       1        Kolkata Knight Riders
# ...

# %%
deliveries.batsman[(deliveries['batsman_runs']==6)].value_counts()
# Out:
# CH Gayle          252
# RG Sharma         164
# SK Raina          161
# V Kohli           149
# YK Pathan         143
# AB de Villiers    142
# MS Dhoni          140
# DA Warner         134
# Yuvraj Singh      133
# KA Pollard        125
# SR Watson         121
# DR Smith          109
# BB McCullum       106
# V Sehwag          106
# RV Uthappa        104
# AC Gilchrist       92
# M Vijay            89
# JP Duminy          78
# NV Ojha            76
# AT Rayudu          76
# DA Miller          74
# SE Marsh           73
# S Dhawan           62
# KD Karthik         60
# DJ Hussey          60
# GJ Maxwell         56
# JA Morkel          55
# MK Pandey          53
# RA Jadeja          53
# MEK Hussey         52
#                  ...
# CK Langeveldt       1
# M Kartik            1
# RR Powar            1
# Anureet Singh       1
# NL McCullum         1
# GH Vihari           1
# RR Raje             1
# DE Bollinger        1
# KW Richardson       1
# AC Thomas           1
# ...

# %%
deliveries.batsman[(deliveries['batsman']=='BB McCullum') & (deliveries['total_runs'])]
# Out:
# 2         BB McCullum
# 6         BB McCullum
# 17        BB McCullum
# 19        BB McCullum
# 21        BB McCullum
# 30        BB McCullum
# 32        BB McCullum
# 38        BB McCullum
# 40        BB McCullum
# 43        BB McCullum
# 45        BB McCullum
# 47        BB McCullum
# 49        BB McCullum
# 53        BB McCullum
# 57        BB McCullum
# 61        BB McCullum
# 62        BB McCullum
# 71        BB McCullum
# 78        BB McCullum
# 80        BB McCullum
# 81        BB McCullum
# 84        BB McCullum
# 98        BB McCullum
# 100       BB McCullum
# 107       BB McCullum
# 111       BB McCullum
# 116       BB McCullum
# 1059      BB McCullum
# 2609      BB McCullum
# 2614      BB McCullum
#              ...
# 132834    BB McCullum
# 132841    BB McCullum
# 132845    BB McCullum
# 132853    BB McCullum
# 134322    BB McCullum
# 134325    BB McCullum
# 135034    BB McCullum
# 135038    BB McCullum
# 135040    BB McCullum
# 135051    BB McCullum
# ...

# %%
R=deliveries.groupby('batsman').sum()['batsman_runs']

# %%
B=deliveries.groupby('batsman').sum()['ball']

# %%
B
# Out:
# batsman
# A Ashish Reddy            720
# A Chandila                 23
# A Chopra                  273
# A Flintoff                203
# A Kumble                  192
# A Mishra                 1209
# A Mithun                   94
# A Mukund                   93
# A Nehra                   267
# A Singh                    42
# A Symonds                2823
# A Uniyal                   21
# A Zampa                     6
# AA Bilakhia               320
# AA Chavan                  40
# AA Jhunjhunwala           816
# AA Noffke                  43
# AB Agarkar                624
# AB Barath                 160
# AB Dinda                  186
# AB McDonald               357
# AB de Villiers           8078
# AC Blizzard               309
# AC Gilchrist             5413
# AC Thomas                  70
# AC Voges                  507
# AD Mascarenhas            294
# AD Mathews               2045
# AD Nath                    94
# AD Russell               1388
#                         ...
# ...

# %%
R
# Out:
# batsman
# A Ashish Reddy           280
# A Chandila                 4
# A Chopra                  53
# A Flintoff                62
# A Kumble                  35
# A Mishra                 291
# A Mithun                  34
# A Mukund                  19
# A Nehra                   41
# A Singh                    2
# A Symonds                974
# A Uniyal                   4
# A Zampa                    0
# AA Bilakhia               69
# AA Chavan                 12
# AA Jhunjhunwala          217
# AA Noffke                  9
# AB Agarkar               179
# AB Barath                 42
# AB Dinda                  19
# AB McDonald              123
# AB de Villiers          3270
# AC Blizzard              120
# AC Gilchrist            2069
# AC Thomas                 20
# AC Voges                 181
# AD Mascarenhas            79
# AD Mathews               692
# AD Nath                   20
# AD Russell               574
#                         ...
# ...

# %%
BB=B.sort_values(ascending=False)

# %%
Strike_rate=(R/B)*100

# %%
S=Strike_rate.sort_values(ascending=False)

# %%
pd.concat([BB,S],axis=1).sort_values('ball',ascending=False)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                      ball          0
# V Kohli             11432  35.995451
# SK Raina            11149  36.828415
# G Gambhir           10823  33.576642
# RG Sharma           10607  36.523051
# RV Uthappa           9559  35.463961
# S Dhawan             9343  32.987263
# MS Dhoni             8811  37.112700
# DA Warner            8572  39.349043
# CH Gayle             8553  40.348416
# JH Kallis            8122  29.881803
# AB de Villiers       8078  40.480317
# AM Rahane            7897  33.873623
# KD Karthik           7479  33.988501
# SR Tendulkar         7375  31.647458
# ...

# %%
P=deliveries.batsman[(deliveries['dismissal_kind']=='bowled')& (deliveries['over']>=16)&(deliveries['inning']==2)].value_counts()

# %%
k=[i for i, val in enumerate(P>2) if val]

# %%
for i in k:
    print('player is {}'.format(deliveries.batsman[i]))
# Out:
# player is SC Ganguly
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is SC Ganguly
# player is SC Ganguly
# player is SC Ganguly
# player is BB McCullum
# player is BB McCullum
# player is SC Ganguly
# player is BB McCullum
# player is BB McCullum
# player is BB McCullum
# player is SC Ganguly
# player is SC Ganguly
# player is SC Ganguly
# player is BB McCullum

# %%
deliveries.groupby('bowler').sum()['ball']
# Out:
# bowler
# A Ashish Reddy       962
# A Chandila           819
# A Flintoff           231
# A Kumble            3488
# A Mishra            8838
# A Mithun            1182
# A Nehra             6664
# A Nel                 63
# A Singh             1738
# A Symonds           1936
# A Uniyal             140
# A Zampa              364
# AA Chavan            913
# AA Jhunjhunwala      317
# AA Kazi               49
# AA Noffke             91
# AB Agarkar          3006
# AB Dinda            5569
# AB McDonald          665
# AC Gilchrist           1
# AC Thomas           1185
# AC Voges             203
# AD Mascarenhas      1098
# AD Mathews          2761
# AD Russell          2344
# AF Milne              91
# AG Murtaza           959
# AJ Finch             155
# AL Menaria           402
# AM Nayar             865
#                     ...
# T Henderson          126
# T Shamsi             336
# T Thushara           528
# TA Boult             779
# TG Southee          2279
# ...

# %%
deliveries.groupby('bowler').sum()['total_runs']
# Out:
# bowler
# A Ashish Reddy       400
# A Chandila           245
# A Flintoff           106
# A Kumble            1089
# A Mishra            2960
# A Mithun             477
# A Nehra             2339
# A Nel                 31
# A Singh              639
# A Symonds            694
# A Uniyal              67
# A Zampa              117
# AA Chavan            339
# AA Jhunjhunwala      130
# AA Kazi               21
# AA Noffke             41
# AB Agarkar          1174
# AB Dinda            1982
# AB McDonald          263
# AC Gilchrist           0
# AC Thomas            416
# AC Voges              76
# AD Mascarenhas       365
# AD Mathews          1038
# AD Russell           917
# AF Milne              44
# AG Murtaza           322
# AJ Finch              67
# AL Menaria           144
# AM Nayar             323
#                     ...
# T Henderson           41
# T Shamsi             151
# T Thushara           164
# TA Boult             278
# TG Southee           833
# ...
